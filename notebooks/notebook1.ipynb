# %% [markdown]
# # Predicting stock prices

# %% [markdown]
# ## Data preprocessing

# %%
from random import random

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/World-Stock-Prices-Dataset.csv', sep = ";")

# %%
df.head(5)
# Out:
#                         Date        Open        High         Low      Volume  \
# 0  2024-08-23 00:00:00-04:00    4.400000    4.970000    4.120000  80045218.0
# 1  2024-08-23 00:00:00-04:00  214.455002  221.470001  214.210007  81224795.0
# 2  2024-08-23 00:00:00-04:00  882.489990  884.556030  871.668396   1227798.0
# 3  2024-08-23 00:00:00-04:00  177.190002  178.969894  175.240005  28213962.0
# 4  2024-08-23 00:00:00-04:00  225.658997  228.220001  224.339996  38607139.0
#
#   Brand_Name Ticker Industry_Tag Country  Dividends  Stock Splits       Close
# 0    peloton   PTON      fitness     usa        0.0           0.0    4.840000
# 1      tesla   TSLA   automotive     usa        0.0           0.0  220.320007
# 2     costco   COST       retail     usa        0.0           0.0  879.210022
# 3     amazon   AMZN   e-commerce     usa        0.0           0.0  177.039993
# 4      apple   AAPL   technology     usa        0.0           0.0  226.839996

# %%
X = df.iloc[:,1:5]
y = df.iloc[:, -1]

# %% [markdown]
# ## Checking for missing values

# %%
df.isnull().sum()
# Out:
# Date            0
# Open            0
# High            0
# Low             0
# Volume          0
# Brand_Name      0
# Ticker          0
# Industry_Tag    0
# Country         0
# Dividends       0
# Stock Splits    0
# Close           0
# dtype: int64

# %% [markdown]
# ## Train Test Slit

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
print(X_train)
# Out:
#               Open        High         Low      Volume
# 227321   13.016673   13.083188   12.709964  29119000.0
# 178249    2.866956    3.029799    2.839433  69624800.0
# 101622  180.729996  182.899994  180.649994   4227900.0
# 219221   27.799544   28.147632   27.475189   2639733.0
# 244038    6.020000    6.127500    5.925000   8906000.0
# ...            ...         ...         ...         ...
# 211543    8.957410    9.206938    8.567123   2417700.0
# 86293     5.362004    5.362004    5.229813    106100.0
# 122579   12.017695   12.255588   11.935663   5595100.0
# 152315   29.292773   29.477006   29.234155  27433500.0
# 117952   35.866001   36.400002   35.827000  58408000.0
#
# [235744 rows x 4 columns]

# %% [markdown]
# ## Feature Scaling in the Features

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %% [markdown]
# ## Training the Polynomial Regression Model in the training set

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_regressor = PolynomialFeatures(degree = 2, include_bias = False)
X_poly = poly_regressor.fit_transform(X)

from sklearn.linear_model import LinearRegression
lin_regressor = LinearRegression()
lin_regressor.fit(X_poly, y)
# Out:
# LinearRegression()

# %%
print(X_poly)
# Out:
# [[4.40000010e+00 4.96999979e+00 4.11999989e+00 ... 1.69743991e+01
#   3.29786289e+08 6.40723692e+15]
#  [2.14455002e+02 2.21470001e+02 2.14210007e+02 ... 4.58859270e+04
#   1.73991639e+10 6.59746732e+15]
#  [8.82489990e+02 8.84556030e+02 8.71668396e+02 ... 7.59805793e+05
#   1.07023271e+09 1.50748793e+12]
#  ...
#  [1.66935660e+01 1.67556238e+01 1.59488716e+01 ... 2.54366504e+02
#   1.17772847e+08 5.45293634e+13]
#  [7.53447745e+00 7.53447745e+00 7.36359146e+00 ... 5.42224792e+01
#   3.61449250e+06 2.40943540e+11]
#  [5.73167484e+00 5.79397541e+00 5.42795873e+00 ... 2.94627360e+01
#   3.16216592e+07 3.39387805e+13]]

# %%
lin_regressor.predict(poly_regressor.fit_transform([[223, 226, 224, 400000]]))
# Out:
# array([225.32120615])
